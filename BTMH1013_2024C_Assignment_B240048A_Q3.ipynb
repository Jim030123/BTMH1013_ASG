# %% [markdown]
# <a href="https://colab.research.google.com/github/Jim030123/BTMH1013_ASG/blob/main/BTMH1013_2024C_Assignment_B240048A_Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit folium streamlit_folium
# Out:
# Collecting streamlit
#   Downloading streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.19.2)
# Collecting streamlit_folium
#   Downloading streamlit_folium-0.24.0-py3-none-any.whl.metadata (413 bytes)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.9.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (1.18.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 11.5 MB/s eta 0:00:00
# Downloading streamlit_folium-0.24.0-py3-none-any.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.5/328.5 kB 23.7 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 22.9 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit, streamlit_folium
# Successfully installed pydeck-0.9.1 streamlit-1.41.1 streamlit_folium-0.24.0 watchdog-6.0.0

# %% [markdown]
# Q3 (a) Data preparation

# %%
attractions = [
    {"name": "Petronas Twin Towers", "lat": 3.1579, "lon": 101.7123, "type": "Historical Site", "desc": "Iconic skyscrapers in Kuala Lumpur."},
    {"name": "Langkawi Sky Bridge", "lat": 6.3783, "lon": 99.6653, "type": "Natural Wonder", "desc": "Stunning bridge offering panoramic views."},
    {"name": "Sunway Lagoon", "lat": 3.0730, "lon": 101.6076, "type": "Amusement Park", "desc": "Famous theme park in Malaysia."},
    {"name": "Batu Caves", "lat": 3.2379, "lon": 101.6831, "type": "Historical Site", "desc": "Sacred Hindu temple and caves."},
    {"name": "Mount Kinabalu", "lat": 6.0750, "lon": 116.5581, "type": "Natural Wonder", "desc": "Malaysia's highest peak."},
    {"name": "George Town", "lat": 5.4141, "lon": 100.3288, "type": "Cultural Heritage", "desc": "UNESCO World Heritage Site known for its historical architecture."},
    {"name": "Taman Negara", "lat": 4.3847, "lon": 102.4044, "type": "Natural Wonder", "desc": "Oldest tropical rainforest in the world."},
    {"name": "Kek Lok Si Temple", "lat": 5.4008, "lon": 100.2730, "type": "Religious Site", "desc": "Largest Buddhist temple in Malaysia."},
    {"name": "Perhentian Islands", "lat": 5.9068, "lon": 102.7276, "type": "Beach", "desc": "Crystal-clear waters and white sandy beaches."},
    {"name": "Legoland Malaysia", "lat": 1.4262, "lon": 103.6319, "type": "Amusement Park", "desc": "Family-friendly theme park in Johor."},
    {"name": "Sepilok Orangutan Rehabilitation Centre", "lat": 5.8674, "lon": 117.9624, "type": "Wildlife Sanctuary", "desc": "Center for orphaned and rescued orangutans."},
    {"name": "Cameron Highlands", "lat": 4.4700, "lon": 101.3779, "type": "Natural Wonder", "desc": "Famous for tea plantations and cool weather."},
    {"name": "Melaka City", "lat": 2.1896, "lon": 102.2501, "type": "Cultural Heritage", "desc": "UNESCO World Heritage Site with rich history."},
    {"name": "Pangkor Island", "lat": 4.2300, "lon": 100.5533, "type": "Beach", "desc": "Secluded island with pristine beaches."},
    {"name": "Aquaria KLCC", "lat": 3.1559, "lon": 101.7133, "type": "Aquarium", "desc": "State-of-the-art oceanarium in Kuala Lumpur."},
    {"name": "Gunung Mulu National Park", "lat": 4.0488, "lon": 114.8126, "type": "Natural Wonder", "desc": "Famous for caves and karst formations."},
    {"name": "Sipadan Island", "lat": 4.1149, "lon": 118.6289, "type": "Marine Sanctuary", "desc": "One of the world’s best diving destinations."},
    {"name": "Putrajaya Botanical Garden", "lat": 2.9434, "lon": 101.6991, "type": "Garden", "desc": "Malaysia's largest botanical garden."},
    {"name": "Johor Bahru Old Chinese Temple", "lat": 1.4615, "lon": 103.7632, "type": "Religious Site", "desc": "Historic Chinese temple in Johor."},
    {"name": "Penang Hill", "lat": 5.4194, "lon": 100.2766, "type": "Natural Wonder", "desc": "Cool retreat with panoramic views of Penang."}
]

# %% [markdown]
# 3(c) Customisations

# %%
# Import libraries
import folium
from IPython.display import display, HTML

# Prepare dummy dataset


# Create map object centered in Malaysia
my_map = folium.Map(location=[4.2105, 101.9758], zoom_start=6)

# Add attractions to the map
for attraction in attractions:
    popup = f"<b>{attraction['name']}</b><br>{attraction['desc']}"
    folium.Marker(
        location=[attraction["lat"], attraction["lon"]],
        popup=folium.Popup(popup, max_width=300)
    ).add_to(my_map)



# Save map to an HTML file
my_map.save("tourist_map.html")

# Display the map directly in Jupyter or Colab
display(HTML(my_map._repr_html_()))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78e2d109d77332cee4aef0b10f437224 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78e2d109d77332cee4aef0b10f437224&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78e2d109d77332cee4aef0b10f437224 = L.map(
#                 &quot;map_78e2d109d77332cee4aef0b10f437224&quot;,
#                 {
#                     center: [4.2105, 101.9758],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec4aae4d6b272ce3f99cc53af634de89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec4aae4d6b272ce3f99cc53af634de89.addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#             var marker_3fa8e1a9a1b981d9ddb42f2dbb8e0e4b = L.marker(
#                 [3.1579, 101.7123],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_475048aed49db0bc6dcd50e5a5d2df51 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7cb92bfcc18a509e3a83284e308349f2 = $(`&lt;div id=&quot;html_7cb92bfcc18a509e3a83284e308349f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Petronas Twin Towers&lt;/b&gt;&lt;br&gt;Iconic skyscrapers in Kuala Lumpur.&lt;/div&gt;`)[0];
#                 popup_475048aed49db0bc6dcd50e5a5d2df51.setContent(html_7cb92bfcc18a509e3a83284e308349f2);
#
#
#
#         marker_3fa8e1a9a1b981d9ddb42f2dbb8e0e4b.bindPopup(popup_475048aed49db0bc6dcd50e5a5d2df51)
#         ;
#
#
#
#
#             var marker_c483c41304496ae74ed73124ab66a7c5 = L.marker(
#                 [6.3783, 99.6653],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_0ba437d1a86a93cf07e8fbd314567acb = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_665c8927c1b474ace21f79cca4f8c50a = $(`&lt;div id=&quot;html_665c8927c1b474ace21f79cca4f8c50a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Langkawi Sky Bridge&lt;/b&gt;&lt;br&gt;Stunning bridge offering panoramic views.&lt;/div&gt;`)[0];
#                 popup_0ba437d1a86a93cf07e8fbd314567acb.setContent(html_665c8927c1b474ace21f79cca4f8c50a);
#
#
#
#         marker_c483c41304496ae74ed73124ab66a7c5.bindPopup(popup_0ba437d1a86a93cf07e8fbd314567acb)
#         ;
#
#
#
#
#             var marker_d3b5419ffc732968d0ba03381cbd6b23 = L.marker(
#                 [3.073, 101.6076],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_6c2dcb219ebcc7c2139868f69069daa4 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_9063898b36e198ba3b9ccf7b8fe57905 = $(`&lt;div id=&quot;html_9063898b36e198ba3b9ccf7b8fe57905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Sunway Lagoon&lt;/b&gt;&lt;br&gt;Famous theme park in Malaysia.&lt;/div&gt;`)[0];
#                 popup_6c2dcb219ebcc7c2139868f69069daa4.setContent(html_9063898b36e198ba3b9ccf7b8fe57905);
#
#
#
#         marker_d3b5419ffc732968d0ba03381cbd6b23.bindPopup(popup_6c2dcb219ebcc7c2139868f69069daa4)
#         ;
#
#
#
#
#             var marker_5b27b4c489606d7f3461429a1c24b20e = L.marker(
#                 [3.2379, 101.6831],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_4a93520c3d29c0f98be8267abeb5bc67 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_8c1cdb7abaeb7d396289f646da36075c = $(`&lt;div id=&quot;html_8c1cdb7abaeb7d396289f646da36075c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Batu Caves&lt;/b&gt;&lt;br&gt;Sacred Hindu temple and caves.&lt;/div&gt;`)[0];
#                 popup_4a93520c3d29c0f98be8267abeb5bc67.setContent(html_8c1cdb7abaeb7d396289f646da36075c);
#
#
#
#         marker_5b27b4c489606d7f3461429a1c24b20e.bindPopup(popup_4a93520c3d29c0f98be8267abeb5bc67)
#         ;
#
#
#
#
#             var marker_4747437f2d53fe09f60678724984c2b0 = L.marker(
#                 [6.075, 116.5581],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_afc250186276d675b1e31e19423945fc = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_574dfcba113dd6ca016aa9911dea5d7d = $(`&lt;div id=&quot;html_574dfcba113dd6ca016aa9911dea5d7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Mount Kinabalu&lt;/b&gt;&lt;br&gt;Malaysia&#x27;s highest peak.&lt;/div&gt;`)[0];
#                 popup_afc250186276d675b1e31e19423945fc.setContent(html_574dfcba113dd6ca016aa9911dea5d7d);
#
#
#
#         marker_4747437f

# %% [markdown]
# 3(d) Additional features

# %%
# Import libraries
import folium
from IPython.display import display, HTML

# Create map object centered in Malaysia

# Color coding based on type
color_map = {
    "Historical Site": "blue",
    "Natural Wonder": "green",
    "Amusement Park": "red",
    "Cultural Heritage": "yellow",
    "Religious Site": "purple",
    "Beach": "orange",
    "Aquarium": "cadetblue",
    "Wildlife Sanctuary": "pink",
    "Marine Sanctuary": "darkred",
    "Garden": "darkgreen"
}

# Layer controls dictionary
layers = {}

# Add attractions to the map
for attraction in attractions:
    attr_type = attraction["type"]
    if attr_type not in layers:
        layers[attr_type] = folium.FeatureGroup(name=attr_type)

    popup = f"<b>{attraction['name']}</b><br>{attraction['desc']}"
    folium.Marker(
        location=[attraction["lat"], attraction["lon"]],
        popup=folium.Popup(popup, max_width=300),
        icon=folium.Icon(color=color_map.get(attr_type, "gray"))
    ).add_to(layers[attr_type])

# Add layers to the map
for layer in layers.values():
    layer.add_to(my_map)

# Add layer control
folium.LayerControl().add_to(my_map)



# Save map to an HTML file
my_map.save("tourist_map.html")

# Display the map directly in Jupyter or Colab
display(HTML(my_map._repr_html_()))
# Out:
# <ipython-input-34-fa317245cdd6>:34: UserWarning: color argument of Icon should be one of: {'purple', 'pink', 'cadetblue', 'lightblue', 'gray', 'black', 'darkgreen', 'red', 'beige', 'green', 'lightgreen', 'white', 'orange', 'blue', 'darkpurple', 'lightred', 'lightgray', 'darkred', 'darkblue'}.
#   icon=folium.Icon(color=color_map.get(attr_type, "gray"))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78e2d109d77332cee4aef0b10f437224 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78e2d109d77332cee4aef0b10f437224&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78e2d109d77332cee4aef0b10f437224 = L.map(
#                 &quot;map_78e2d109d77332cee4aef0b10f437224&quot;,
#                 {
#                     center: [4.2105, 101.9758],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec4aae4d6b272ce3f99cc53af634de89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec4aae4d6b272ce3f99cc53af634de89.addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#             var marker_3fa8e1a9a1b981d9ddb42f2dbb8e0e4b = L.marker(
#                 [3.1579, 101.7123],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_475048aed49db0bc6dcd50e5a5d2df51 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7cb92bfcc18a509e3a83284e308349f2 = $(`&lt;div id=&quot;html_7cb92bfcc18a509e3a83284e308349f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Petronas Twin Towers&lt;/b&gt;&lt;br&gt;Iconic skyscrapers in Kuala Lumpur.&lt;/div&gt;`)[0];
#                 popup_475048aed49db0bc6dcd50e5a5d2df51.setContent(html_7cb92bfcc18a509e3a83284e308349f2);
#
#
#
#         marker_3fa8e1a9a1b981d9ddb42f2dbb8e0e4b.bindPopup(popup_475048aed49db0bc6dcd50e5a5d2df51)
#         ;
#
#
#
#
#             var marker_c483c41304496ae74ed73124ab66a7c5 = L.marker(
#                 [6.3783, 99.6653],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_0ba437d1a86a93cf07e8fbd314567acb = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_665c8927c1b474ace21f79cca4f8c50a = $(`&lt;div id=&quot;html_665c8927c1b474ace21f79cca4f8c50a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Langkawi Sky Bridge&lt;/b&gt;&lt;br&gt;Stunning bridge offering panoramic views.&lt;/div&gt;`)[0];
#                 popup_0ba437d1a86a93cf07e8fbd314567acb.setContent(html_665c8927c1b474ace21f79cca4f8c50a);
#
#
#
#         marker_c483c41304496ae74ed73124ab66a7c5.bindPopup(popup_0ba437d1a86a93cf07e8fbd314567acb)
#         ;
#
#
#
#
#             var marker_d3b5419ffc732968d0ba03381cbd6b23 = L.marker(
#                 [3.073, 101.6076],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_6c2dcb219ebcc7c2139868f69069daa4 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_9063898b36e198ba3b9ccf7b8fe57905 = $(`&lt;div id=&quot;html_9063898b36e198ba3b9ccf7b8fe57905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Sunway Lagoon&lt;/b&gt;&lt;br&gt;Famous theme park in Malaysia.&lt;/div&gt;`)[0];
#                 popup_6c2dcb219ebcc7c2139868f69069daa4.setContent(html_9063898b36e198ba3b9ccf7b8fe57905);
#
#
#
#         marker_d3b5419ffc732968d0ba03381cbd6b23.bindPopup(popup_6c2dcb219ebcc7c2139868f69069daa4)
#         ;
#
#
#
#
#             var marker_5b27b4c489606d7f3461429a1c24b20e = L.marker(
#                 [3.2379, 101.6831],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_4a93520c3d29c0f98be8267abeb5bc67 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_8c1cdb7abaeb7d396289f646da36075c = $(`&lt;div id=&quot;html_8c1cdb7abaeb7d396289f646da36075c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Batu Caves&lt;/b&gt;&lt;br&gt;Sacred Hindu temple and caves.&lt;/div&gt;`)[0];
#                 popup_4a93520c3d29c0f98be8267abeb5bc67.setContent(html_8c1cdb7abaeb7d396289f646da36075c);
#
#
#
#         marker_5b27b4c489606d7f3461429a1c24b20e.bindPopup(popup_4a93520c3d29c0f98be8267abeb5bc67)
#         ;
#
#
#
#
#             var marker_4747437f2d53fe09f60678724984c2b0 = L.marker(
#                 [6.075, 116.5581],
#                 {
# }
#             ).addTo(map_78e2d109d77332cee4aef0b10f437224);
#
#
#         var popup_afc250186276d675b1e31e19423945fc = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_574dfcba113dd6ca016aa9911dea5d7d = $(`&lt;div id=&quot;html_574dfcba113dd6ca016aa9911dea5d7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Mount Kinabalu&lt;/b&gt;&lt;br&gt;Malaysia&#x27;s highest peak.&lt;/div&gt;`)[0];
#                 popup_afc250186276d675b1e31e19423945fc.setContent(html_574dfcba113dd6ca016aa9911dea5d7d);
#
#
#
#         marker_4747437f

# %%
code = '''
import folium
from IPython.display import display, HTML
import streamlit as st
from streamlit_folium import st_folium

# Prepare dummy dataset
attractions = [
    {"name": "Petronas Twin Towers", "lat": 3.1579, "lon": 101.7123, "type": "Historical Site", "desc": "Iconic skyscrapers in Kuala Lumpur."},
    {"name": "Langkawi Sky Bridge", "lat": 6.3783, "lon": 99.6653, "type": "Natural Wonder", "desc": "Stunning bridge offering panoramic views."},
    {"name": "Sunway Lagoon", "lat": 3.0730, "lon": 101.6076, "type": "Amusement Park", "desc": "Famous theme park in Malaysia."},
    {"name": "Batu Caves", "lat": 3.2379, "lon": 101.6831, "type": "Historical Site", "desc": "Sacred Hindu temple and caves."},
    {"name": "Mount Kinabalu", "lat": 6.0750, "lon": 116.5581, "type": "Natural Wonder", "desc": "Malaysia's highest peak."},
]

# Create map object centered in Malaysia
my_map = folium.Map(location=[4.2105, 101.9758], zoom_start=6)

# Color coding based on type
color_map = {"Historical Site": "blue", "Natural Wonder": "green", "Amusement Park": "red"}

# Layer controls dictionary
layers = {"Historical Site": folium.FeatureGroup(name="Historical Sites"),
          "Natural Wonder": folium.FeatureGroup(name="Natural Wonders"),
          "Amusement Park": folium.FeatureGroup(name="Amusement Parks")}

# Add attractions to the map
for attraction in attractions:
    popup = f"<b>{attraction['name']}</b><br>{attraction['desc']}"
    folium.Marker(
        location=[attraction["lat"], attraction["lon"]],
        popup=folium.Popup(popup, max_width=300),
        icon=folium.Icon(color=color_map[attraction["type"]])
    ).add_to(layers[attraction["type"]])

# Add layers to the map
for layer in layers.values():
    layer.add_to(my_map)

# Add layer control
folium.LayerControl().add_to(my_map)

# Display total attractions
total_attractions = len(attractions)
folium.map.Marker(
    [4.0, 101.5],
    icon=folium.DivIcon(
        html=f'<div style="font-size: 12pt; color : black">Total Attractions: {total_attractions}</div>'
    ),
).add_to(my_map)

# Display the map in Streamlit
st.title("Tourist Map of Malaysia")
st_map = st_folium(my_map, width=600, height=600)

# Show the count of total attractions
st.write(f"**Total Number Of Attractions:** {total_attractions}")
'''

with open('tourist_attractions_map.py', 'w') as file:
    file.write(code)

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 35.190.161.200

# %%
# !streamlit run tourist_attractions_map.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠙⠹
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.190.161.200:8501
#
# ⠸⠼⠴your url is: https://all-rivers-taste.loca.lt
